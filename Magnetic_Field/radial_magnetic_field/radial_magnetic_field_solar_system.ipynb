# %%
import numpy as np

# %%
from astropy import constants as const
from astropy import units as u
from math import pi

# Constantes

r_s = const.R_sun.to(u.m).value.item() #UA
m_s= const.M_sun.to(u.kg).value.item() #kg
M_t= const.M_earth.to(u.kg).value.item() #kg
R_t= const.R_earth.to(u.m).value.item() #km
a=1.496e+11#m

# %%
pi
# Out:
# 3.141592653589793

# %%
def campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho):
    
    Br=2*mi_0**(3/2)*sigma*U**2*(Rd-Rdi)**4*np.sqrt(rho)/(4*20*Rd**3) #Tesla

    return Br

# %%
def campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp):
    
    Br=2*mi_0**(3/2)*sigma*U**2*(Rd-Rdi)**4*np.sqrt(rho)/(20*4*Rp**3) #Tesla

    return Br

# %%
def erro_campo(D, rp, rho, B, sigma_D, sigma_rho, sigma_rp):
    sigma=B*np.sqrt(4*(sigma_D/D)**2+(sigma_rho/(2*rho))**2+9*(sigma_rp/rp)**2)
    return sigma

# %% [markdown]
# # Application for Solar System Objects
# - Using parameters obtained from the literature for the internal structure of the objects. Represented by 1
# - Using parameters obtained from the ROWs model. Represented by 2

# %% [markdown]
# # Earth

# %%
# Earth field 1

mi_0=4*np.pi*10**(-7) #magnetic permeability in vacuum
sigma=5*10**5 #electrical conductivity of the core (pure liquid iron)
U=5*10**(-4) # characteristic velocity
Rd=0.55*R_t # outer radius of the dynamo
Rdi=0.19*R_t # inner radius of the dynamo
rho=11000 # Density of the core material (pure iron). It differs from the density of the core itself.
Rp=R_t #Planet's radius


B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup)
# Out:
# 4.946095385427214e-05

# %%
# Earth field 2

mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.552*R_t 
Rdi=0.222*R_t 
rho=11143.0 
Rp=R_t 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(5.144967872925687e-05)

# %%
U
# Out:
# 0.0006049296264894898

# %% [markdown]
# # Mercurio

# %%
# Mercury 1
R_mercury=0.38*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.75*R_mercury 
Rdi=0.5*R_mercury 
rho=8000 
U=30/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, R_mercury)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(9.258863294786102e-08)

# %%
# Mercury 2
R_mercury=0.38*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.729*R_mercury 
Rdi=0.333*R_mercury 
rho=9113.0 
U=30/((Rd-Rdi)*mi_0*sigma) 


B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, R_mercury)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(2.479440655218735e-07)

# %%
# Mercury 2
R_mercury=0.38*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.49*R_mercury 
Rdi=0.0*R_mercury 
rho=9113.0 
U=30/((Rd-Rdi)*mi_0*sigma) 


B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, R_mercury)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(3.796256130229178e-07)

# %% [markdown]
# #  Venus

# %% [markdown]
# # Venus 1
# There are no values listed for the item.

# %%
# Venus 2
R_v=0.95*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.479*R_v 
Rdi=0.479*R_v 
rho=8000 
U=5*10**(-4)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, R_v)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(0.0)

# %% [markdown]
# # Mars

# %% [markdown]
# # Mars 1
# There are no values listed for the item.

# %%
# Mars 2.1
Rp=0.532*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.44*Rp 
Rdi=0.0*Rp 
rho=8143.0 
U=100/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(2.2842220739645024e-06)

# %%
# Mars 2.2
Rp=0.532*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.44*Rp 
Rdi=0.0*Rp 
rho=8143.0 
U=800/((Rd-Rdi)*0.63)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(0.00014619021273372816)

# %% [markdown]
# # Moon

# %% [markdown]
# # Moon 1
# There are no values listed for the item.

# %%
# Moon 2.1
Rp=0.27*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.224*Rp 
Rdi=0.0*Rp
rho=8093.0 
U=10/((Rd-Rdi)*0.63)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(1.1628921228625142e-08)

# %%
# Lua 2.1
Rp=0.27*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.224*Rp
Rdi=0.0*Rp 
rho=8093.0 
U=100/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(1.162892122862514e-06)

# %% [markdown]
# # Ganymedes

# %%
# Ganymedes 1.1
Rp=0.413*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.3*Rp 
Rdi=0.0*Rp 
rho=6000 
U=10/((Rd-Rdi)*0.63) 



B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(1.1741415825859617e-08)

# %%
# Ganymedes 1.2
Rp=0.413*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5
Rd=0.3*Rp 
Rdi=0.0*Rp 
rho=6000 
U=100/((Rd-Rdi)*0.63) 



B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(1.174141582585962e-06)

# %%
# Ganymedes 2.1
Rp=0.413*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.195*Rp 
Rdi=0.0*Rp 
rho=7511 
U=10/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(5.550350867538372e-09)

# %%
# Ganymedes 2.2
Rp=0.413*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.195*Rp 
Rdi=0.0*Rp 
rho=7511 
U=100/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(5.550350867538372e-07)

# %% [markdown]
# # IO

# %%
# IO 

Rp=0.286*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.30*Rp 
Rdi=0.0*Rp 
rho=6000 
U=10/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(1.6955261314965114e-08)

# %%
# IO 

Rp=0.286*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.30*Rp 
Rdi=0.0*Rp 
rho=6000 
U=100/((Rd-Rdi)*0.63)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(1.6955261314965118e-06)

# %% [markdown]
# # EUROPE

# %% [markdown]
# # EUROPE 1
#
# There are no values listed for the item.

# %%
# EUROPE 2.1

Rp=0.25*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.121*Rp
Rdi=0.0*Rp
rho=7583 
U=10/((Rd-Rdi)*0.63)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(3.5473467788253385e-09)

# %%
# EUROPE 2.2
Rp=0.25*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.121*Rp 
Rdi=0.0*Rp 
rho=7583 
U=100/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(3.547346778825338e-07)

# %%
(B_r_sup-10**(-7))/(10**(-7))
# Out:
# np.float64(-0.11316330529366542)

# %% [markdown]
# # CALLISTO

# %% [markdown]
# # CALLISTO 1
#
# There are no values ​​listed for the item.

# %%
# CALLISTO 2.1

Rp=0.38*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5
Rd=0.201*Rp 
Rdi=0.0*Rp 
rho=7566 
U=10/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(6.43271147800754e-09)

# %%
# CALLISTO 2.2

Rp=0.38*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.201*Rp 
Rdi=0.0*Rp 
rho=7566 
U=100/((Rd-Rdi)*0.63) 

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)

# %%
B_r_sup
# Out:
# np.float64(1.608177869501885e-07)
