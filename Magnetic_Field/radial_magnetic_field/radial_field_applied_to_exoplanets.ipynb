# %%
import numpy as np

# %%
from astropy import constants as const
from astropy import units as u

# Constants

r_s = const.R_sun.to(u.m).value.item() #UA
m_s= const.M_sun.to(u.kg).value.item() #kg
M_t= const.M_earth.to(u.kg).value.item() #kg
R_t= const.R_earth.to(u.m).value.item() #km
a=1.496e+11#m

# %%
def campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho):
    
    Br=2*mi_0**(3/2)*sigma*U**2*(Rd-Rdi)**4*np.sqrt(rho)/(4*20*Rd**3) #Tesla

    return Br

# %%
def campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp):
    
    Br=2*mi_0**(3/2)*sigma*U**2*(Rd-Rdi)**4*np.sqrt(rho)/(20*4*Rp**3) #Tesla

    return Br

# %%
def tesla_to_Gauss(Br):

    return Br*10**4

# %%
# GJ 1002 b
Rp=1.03*R_t
mi_0=4*np.pi*10**(-7) #magnetic permeability in vacuum
sigma=5*10**5 # magnetic permeability in vacuum
Rd=0.526*Rp # outer radius of the dynamo
Rdi=0.182*Rp # inner radius of the dynamo
rho=11387.0 #Density of the core material (pure iron). It differs from the core's own density.
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 5.487038948654871e-05 0.0003770342560335408

# %%
B_r_sup*10**4
# Out:
# np.float64(0.5487038948654871)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11388.0, 0.345, 0.0005617750858070398)

# %%
# GJ 1002 c
Rp=1.1*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.526*Rp
Rdi=0.184*Rp 
rho=11377.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 5.076064456630955e-05 0.00034879471494426436

# %%
B_r_sup*10**4
# Out:
# np.float64(0.5076064456630955)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11377.0, 0.342, 0.0005306400232363943)

# %%
# GJ 1061 c
Rp=1.18*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.509*Rp 
Rdi=0.209*Rp 
rho=12497.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 3.816076824425424e-05 0.00028937683493811446

# %%
B_r_sup*10**4
# Out:
# np.float64(0.3816076824425424)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (12497.0, 0.30000000000000004, 0.0005639174484224056)

# %%
# GJ 1061 d
Rp=1.16*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.521*Rp 
Rdi=0.235*Rp 
rho=12253.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 3.493405631283682e-05 0.00024702212083865685

# %%
B_r_sup*10**4
# Out:
# np.float64(0.3493405631283682)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (12253.0, 0.2860000000000001, 0.0006017204507521448)

# %%
# GJ 273 b
Rp=1.51*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.184*Rp 
Rdi=0.0*Rp 
rho= 13315.0
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.157931867434795e-05 0.0018587866183805244

# %%
B_r_sup*10**4
# Out:
# np.float64(0.11579318674347949)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13315.0, 0.184, 0.0007184954532879772)

# %%
# GJ 3323 b
Rp=1.23*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.507*Rp 
Rdi=0.219*Rp 
rho= 12906.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 3.4286994412541524e-05 0.00026309072555926334

# %%
B_r_sup*10**4
# Out:
# np.float64(0.34286994412541527)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (12906.0, 0.28800000000000003, 0.0005635353905305205)

# %%
# GJ 682 b
Rp=1.93*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.287*Rp 
Rdi=0.0*Rp 
rho=14608.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 2.308636654657565e-05 0.0009765846563150303

# %%
B_r_sup*10**4
# Out:
# np.float64(0.23086366546575648)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14608.0, 0.287, 0.0003603956901690376)

# %%
# K2-288 B b
Rp=1.9*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.286*Rp 
Rdi=0.0*Rp 
rho=14599.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 2.3280577099513177e-05 0.0009951662578740657

# %%
B_r_sup*10**4
# Out:
# np.float64(0.23280577099513178)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14558.0, 0.28, 0.0003752383021457361)

# %%
# K2-72 e
Rp=1.29*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.425*Rp 
Rdi=0.0*Rp 
rho=13544.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 7.293153336005372e-05 0.0009500545766422633

# %%
B_r_sup*10**4
# Out:
# np.float64(0.7293153336005372)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13544.0, 0.425, 0.00036411632784593084)

# %%
# Kepler-1229 b
Rp=1.4*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.345*Rp 
Rdi=0.0*Rp 
rho=13880.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 4.482895443274374e-05 0.001091695008240109

# %%
B_r_sup*10**4
# Out:
# np.float64(0.4482895443274374)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13880.0, 0.345, 0.0004133059559866079)

# %%
# Kepler-138 e
Rp=0.797*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.494*Rp 
Rdi=0.0*Rp 
rho=9748.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 0.00013530288560772887 0.001122344576158048

# %%
B_r_sup*10**4
# Out:
# np.float64(1.3530288560772887)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (9748.0, 0.494, 0.0005070298455786415)

# %%
# Kepler-1410 b
Rp=1.78*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.236*Rp 
Rdi=0.0*Rp 
rho=14317.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.6756516492043375e-05 0.0012748166569521609

# %%
B_r_sup*10**4
# Out:
# np.float64(0.16756516492043375)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14317.0, 0.23599999999999996, 0.00047521133294022955)

# %%
# Kepler-1544 b
Rp=1.78*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.236*Rp 
Rdi=0.0*Rp 
rho=14453.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.6835915105525733e-05 0.0012808572128788225

# %%
B_r_sup*10**4
# Out:
# np.float64(0.16835915105525734)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14453.0, 0.23599999999999996, 0.00047521133294022955)

# %%
# Kepler-1606 b 
Rp=2.07*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.234*Rp
Rdi=0.0*Rp
rho=13889.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.3952453394576331e-05 0.0010889376361967848

# %%
B_r_sup*10**4
# Out:
# np.float64(0.1395245339457633)

# %%
# Kepler-1638 b
Rp=1.87*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.269*Rp 
Rdi=0.0*Rp 
rho=14582.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 2.0913427859986205e-05 0.0010744058951833355

# %%
B_r_sup*10**4
# Out:
# np.float64(0.20913427859986206)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14582.0, 0.269, 0.00039684865066006315)

# %%
# Kepler-1649 c
Rp=1.06*R_t
mi_0=4*np.pi*10**(-7)
sigma=5*10**5 
Rd=0.525*Rp 
Rdi=0.205*Rp 
rho=11564.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 4.6494529267856205e-05 0.0003213097800607705

# %%
B_r_sup*10**4
# Out:
# np.float64(0.46494529267856205)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11564.0, 0.32000000000000006, 0.0005885223370917794)

# %%
# Kepler-1652 b
Rp=1.6*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.206*Rp 
Rdi=0.0*Rp
rho=13700.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.3894037409055094e-05 0.0015893765562046945

# %%
B_r_sup*10**4
# Out:
# np.float64(0.13894037409055093)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13700.0, 0.206, 0.0006056637643857149)

# %%
# Kepler-186 f
Rp=1.17*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.522*Rp 
Rdi=0.238*Rp 
rho=12362.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 3.430432752451588e-05 0.00024117783993697511

# %%
B_r_sup*10**4
# Out:
# np.float64(0.3430432752451588)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (12362.0, 0.284, 0.000600778791204802)

# %%
# Kepler-283 c
Rp=1.82*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.265*Rp 
Rdi=0.0*Rp
rho=14539.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 2.082290656346409e-05 0.0011189320882857168

# %%
B_r_sup*10**4
# Out:
# np.float64(0.20822906563464091)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14382.0, 0.243, 0.00045137877434434857)

# %%
# Kepler-296 e
Rp=1.53*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.284*Rp 
Rdi=0.0*Rp 
rho=13901.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 2.7817749575377982e-05 0.0012144145810418822

# %%
B_r_sup*10**4
# Out:
# np.float64(0.2781774957537798)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13901.0, 0.284, 0.0004594190756272016)

# %%
# Kepler-296 f
Rp=1.8*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.241*Rp 
Rdi=0.0*Rp 
rho=14338.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.729257190720066e-05 0.001235402462136021

# %%
B_r_sup*10**4
# Out:
# np.float64(0.1729257190720066)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14338.0, 0.241, 0.00046018159691454957)

# %%
# Kepler-440 b
Rp=1.86*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.247*Rp
Rdi=0.0*Rp
rho=14451.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.7647518060093507e-05 0.0011710967486574127

# %%
B_r_sup*10**4
# Out:
# np.float64(0.17647518060093506)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14451.0, 0.247, 0.0004345191257270724)

# %%
# Kepler-441 b
Rp=1.64*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.214*Rp
Rdi=0.0*Rp 
rho=13886.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.4727397245665646e-05 0.0015027428879706313

# %%
B_r_sup*10**4
# Out:
# np.float64(0.14727397245665647)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13886.0, 0.21399999999999997, 0.0005688020764233292)

# %%
# Kepler-442 b
Rp=1.34*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.312*Rp 
Rdi=0.0*Rp 
rho=13217.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 3.737873132542686e-05 0.0012307242977793683

# %%
B_r_sup*10**4
# Out:
# np.float64(0.3737873132542686)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13217.0, 0.312, 0.00047748463629336877)

# %%
# Kepler-452 b
Rp=1.63*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.211*Rp 
Rdi=0.0*Rp 
rho=13819.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.437041588001047e-05 0.0015297553154276391

# %%
B_r_sup*10**4
# Out:
# np.float64(0.1437041588001047)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13819.0, 0.21099999999999997, 0.0005804285079566529)

# %%
# L 98-59 f
Rp=1.48*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.283*Rp 
Rdi=0.0*Rp 
rho=13702.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 2.8350247811403682e-05 0.001250827880281936

# %%
B_r_sup*10**4
# Out:
# np.float64(0.28350247811403684)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13702.0, 0.283, 0.00047661822352576555)

# %%
# LHS 1140 b
Rp=1.73*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.337*Rp 
Rdi=0.0*Rp 
rho=17203.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 3.8536255743174717e-05 0.0010068848651460926

# %%
B_r_sup*10**4
# Out:
# np.float64(0.3853625574317472)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (17203.0, 0.337, 0.0003424071229336231)

# %%
# Proxima Cen b
Rp=1.02*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.528*Rp 
Rdi=0.177*Rp 
rho=11349.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 5.7589934074127785e-05 0.0003912414085362259

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11349.0, 0.3510000000000001, 0.0005575855447783127)

# %%
B_r_sup*10**4
# Out:
# np.float64(0.5758993407412779)

# %%
# Ross 128 b
Rp=1.11*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.511*Rp 
Rdi=0.190*Rp
rho=11970.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 4.545565115320478e-05 0.0003406631697202375

# %%
B_r_sup*10**4
# Out:
# np.float64(0.4545565115320478)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11970.0, 0.32100000000000006, 0.0005602615047052609)

# %%
# Ross 508 b
Rp=1.83*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.273*Rp 
Rdi=0.0*Rp 
rho=14572.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 2.2003284178709908e-05 0.0010814328723681374

# %%
B_r_sup*10**4
# Out:
# np.float64(0.2200328417870991)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14412.0, 0.242, 0.00045076723285356903)

# %%
# TOI-1266 d
Rp=1.74*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.249*Rp 
Rdi=0.0*Rp
rho=14325.0
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.9087562997183136e-05 0.001236381340732562

# %%
B_r_sup*10**4
# Out:
# np.float64(0.19087562997183136)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14269.0, 0.241, 0.00047604992784263745)

# %%
# TOI-700 d
Rp=1.073*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.525*Rp 
Rdi=0.211*Rp 
rho=11643.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 4.4375753976596395e-05 0.00030666755798533296

# %%
B_r_sup*10**4
# Out:
# np.float64(0.44375753976596394)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11643.0, 0.31400000000000006, 0.000592501459511494)

# %%
# TOI-700 e
Rp=0.953*R_t
mi_0=4*np.pi*10**(-7)
sigma=5*10**5 
Rd=0.516*Rp
Rdi=0.0*Rp 
rho=11075.0
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 0.00013159278922072074 0.0009578179846143345

# %%
B_r_sup*10**4
# Out:
# np.float64(1.3159278922072075)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11075.0, 0.516, 0.00040595340853756713)

# %%
# TOI-715 b
Rp=1.55*R_t
mi_0=4*np.pi*10**(-7)
sigma=5*10**5
Rd=0.194*Rp
Rdi=0.0*Rp
rho=13487.0
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.2620691838876374e-05 0.0017285341845979297

# %%
B_r_sup*10**4
# Out:
# np.float64(0.12620691838876374)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13487.0, 0.194, 0.0006638735508531147)

# %%
# Teegarden's Star b
Rp=1.05*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.526*Rp 
Rdi=0.199*Rp 
rho=11503.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 4.888385962901325e-05 0.0003358986480639311

# %%
B_r_sup*10**4
# Out:
# np.float64(0.4888385962901325)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11503.0, 0.327, 0.0005814089900729039)

# %%
# Teegarden's Star c
Rp=1.02*R_t
mi_0=4*np.pi*10**(-7)
sigma=5*10**5 
Rd=0.527*Rp 
Rdi=0.174*Rp  
rho=11344.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 5.8235266885118945e-05 0.0003978819378717593

# %%
B_r_sup*10**4
# Out:
# np.float64(0.5823526688511894)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11344.0, 0.3530000000000001, 0.0005544264198787189)

# %%
# Wolf 1061 c
Rp=1.66*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.216*Rp 
Rdi=0.0*Rp 
rho=13956.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.48605066655424e-05 0.0014745936636253371

# %%
B_r_sup*10**4
# Out:
# np.float64(0.148605066655424)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (13956.0, 0.216, 0.0005567458075120805)

# %%
# Wolf 1069 b
Rp=1.08*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.510*Rp 
Rdi=0.171*Rp
rho=11753.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 5.163019094287541e-05 0.00038921825649920023

# %%
B_r_sup*10**4
# Out:
# np.float64(0.5163019094287541)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (11753.0, 0.339, 0.0005452495813982618)

# %%
# tau Cet f
Rp=1.81*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.259*Rp
Rdi=0.0*Rp 
rho=14449.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.9938549967493826e-05 0.001147609880701123

# %%
B_r_sup*10**4
# Out:
# np.float64(0.19938549967493827)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (14449.0, 0.259, 0.000425834119203762)

# %%
# K2-18 b
Rp=2.37*R_t
mi_0=4*np.pi*10**(-7) 
sigma=5*10**5 
Rd=0.279*Rp
Rdi=0.0*Rp 
rho=17228.0 
U=800/((Rd-Rdi)*mi_0*sigma)

B_r_sup=campo_radial_superficie(mi_0, sigma, U, Rd, Rdi, rho, Rp)
B_r_RD=campo_radial_RD(mi_0, sigma, U, Rd, Rdi, rho)
print(B_r_sup, B_r_RD)
# Out:
# 1.929439717727139e-05 0.0008884205680585901

# %%
B_r_sup*10**4
# Out:
# np.float64(0.1929439717727139)

# %%
rho, (Rd-Rdi)/Rp, U
# Out:
# (17187.0, 0.274, 0.0003074113411893369)
