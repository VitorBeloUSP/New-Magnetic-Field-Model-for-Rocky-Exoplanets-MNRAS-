# %% [markdown]
# # Author: Lena Noack
# # GNU General Public License v3.0 (GPL-3.0)
# #Interior Structure Model

# %%
import numpy as np
import math
import csv
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
from EOS_functions import EOS_rock, EOS_core, EOS_core_mixed
from values import *
from Help_functions import get_Tmelt_MO, get_Tmelt_core, get_Tmelt_water, getphase
from water import getWater

# %% [markdown]
# #Start interior structure model

# %% [markdown]
# # INSERIR A EQ DE TEMPERATURA E PRESSÃO NO CODIOG ABAIXO.

# %%
def temp_pla2(T_e, R_e, a):
    t_p=T_e*(R_e/(2*a))**(1/2)
    return t_p

# Unidades: 1, kg, kg, km, km, adimensional 
def pressao(P_t, M_p, M_t, R_p, R_t, tipo): 
    if tipo == 1: #mercurio
        beta = 1.05*10**(-13)
    elif tipo == 0:#venus
        beta = 108.27
    elif tipo == 2:#marte
        beta = 0.0467
    elif tipo==3 or tipo==4 : #terra
        beta = 1.014
    else:# qualquer outro tipo, vou desconsiderar esses de toda forma.
        beta=1
    P=beta*((M_p/M_t)**2)*((R_t/R_p)**4)*P_t
    return P

# %%
def interior_structure(M,x_Fe_tot,x_H2O_tot, t, P):
  '''
  input:
   M: Mass in Earth masses
   x_Fe_tot: Iron weigth fraction in percent of the entire planet (core + mantle)
   x_H2O_tot: Water weigth fraction in percent of surface water/ice layer
  return:
   Rp_E - planet radius in Earth radii
   MOI - moment of inertia factor
   radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu - profiles of different planetary properties
   mat - material layers (<0 ices, 0 water, >0 different rock and core layers)
  '''

  '''Set initialization parameters'''
  Dcr = 50e3      # thickness of crustal layer in m
  Dlid = 300e3    # thickness of lithosphere, only used to set upper mantle temperature
  Psurf = P     # atmospheric surface pressure
  Tsurf = t     # potential surface temperature in K
  Tlid = 0.0    #2000 # in K; if set to 0, then mantle melt temp is used at Dlid depth to set Tlid
  DTcmb = -1.0  #1500 # in K, T jump at CMB; if set to neg value (e.g. -1), then jump is calculated via melt temp times -DTcmb
  nr = 500         # radial resolution from center of planet to surface
  tol = 0.001     # Convergence parameter
  maxIter = 20   # max number iterations

  # light elements in the core -> array added for molar fractions Si,C,S,O; e.g. (0.2 S -> Fe0.8S0.2), means weight fraction of 12 wt-% S
  xelem = np.array([0.0,0.0,0.2,0.0]) # initial core-averaged value
  xelem_ic = np.array([0.00,0.00,0.07,0.00]) # fixed inner core value (no real partitioning included yet; outer core value calculated during inner core growth

  X_FeM_mol = 0.1 # iron number in mantle (ratio of Fe-bearing molecules divided by Mg- and Fe-bearing molecules)
  X_H2OM = 0      # water content in mantle in wt-%, only used for el cond profile versions 2-4
  ec_model = 1    # electrical conductivity profiles: 1 - Xu, 2 - mat-dep prof without Fe, 3 - as 2 but with Fe dependence, 4 - as 3 but newer parameters


  '''Distribute iron between core and mantle'''

  x_Fe_tot = x_Fe_tot/100 # weight fraction instead of percent
  x_H2O_tot = x_H2O_tot/100
  M = M * 5.972*10**24 # mass in kg
  Mw = M*x_H2O_tot # would need to be reduced by water stored in mantle, not considered here
  G = 6.67384*10**(-11) # gravitational constant in m^3 / (kg s^2)

  # Take Fe in mantle out of x_Fe to obtain x_CMF (core mass fraction based on iron - here light elements not included yet!)
  # Here we assume that mantle is composed of (1-X_FeM_mol)*Mg2SiO4 + X_FeM_mol*Fe2SiO4

  # Molar masses:
  mMg=24.305; mFe=55.845; mSi=28.0855; mO=15.9994

  XmFe = 2*X_FeM_mol*mFe/(X_FeM_mol*2*(mFe-mMg) + 2*mMg+mSi+4*mO) # mantle mass fraction of iron w.r.t. mantle mass

  # x_Fe_tot*M = x_Fe*M + XmFe*Mm = x_Fe*M*(1-XmFe) + XmFe*(M-Mw)
  x_Fe = ( x_Fe_tot*M - XmFe*(M-Mw) ) / (M*(1-XmFe)) # core mass fraction w.r.t. total planet mass
  Mc = x_Fe*M
  if Mc<0.0:
      print("Error, not enough iron in planet to have ",X_FeM_mol," as iron number -> adapt iron number!")
      Mc = 0.0
      x_Fe = 0.0
      XmFe = x_Fe_tot*M / (M-Mw) # adapt XmFe such that all iron is in mantle

      #XmFe * (X_FeM_mol*2*(mFe-mMg) + 2*mMg+mSi+4*mO) = 2*X_FeM_mol*mFe
      X_FeM_mol = XmFe*(2*mMg+mSi+4*mO)/(2*mFe-2*(mFe-mMg)*XmFe) # adapt mantle iron number

  Mm = M - Mc - Mw

  #print('Iron fraction={0:5.3f}, Core IF={1:5.3f}, Mantle Fe#={2:5.3f}, Mantle IF={3:5.3f}\n'
  #      .format(x_Fe_tot,x_Fe,X_FeM_mol,XmFe*Mm/M))

  '''Initialization routines'''

  rho_c = 11000 # guess for core density in kg/m^3
  rho_m = 4000 # guess for mantle density in kg/m^3
  rho_w = 1000 # guess for water density in kg/m^3
  cp_c = 800 # guess for core heat capacity in J/kg K
  cp_m = 1300 # guess for mantle heat capacity in J/kg K
  cp_w = 4200 # guess for water heat capacity in J/kg K
  alpha_c = 0.00001 # guess for core thermal expansion ceoff. in 1/K
  alpha_m = 0.000025 # guess for mantle thermal expansion ceoff. in 1/K
  alpha_w = 0.00007 # guess for water thermal expansion ceoff. in 1/K

  Rc = ( Mc*3.0 / (4.0*math.pi*rho_c) )**(1/3) # first guess core radius
  Rm = ( Mm*3.0 / (4.0*math.pi*rho_m) + Rc**3 )**(1/3) # first guess rocky shell radius
  Rp = ( Mw*3.0 / (4.0*math.pi*rho_w) + Rm**3 )**(1/3) # first guess planet radius

  # Define arrays
  dr = np.zeros(nr) # distance between radius points
  radius = np.zeros(nr) # vector of radii, first radius is dr
  pressure = np.zeros(nr)
  gravity = np.zeros(nr)
  temperature = np.zeros(nr)
  density = np.zeros(nr)
  alpha = np.zeros(nr)
  cp = np.zeros(nr)
  KT = np.zeros(nr)
  KS = np.zeros(nr)
  mu = np.zeros(nr)
  mass = np.zeros(nr)
  mat = np.zeros(nr)
  elcond = np.zeros(nr)

  # set number of grid points in the three layers (core/mantle/water) based on initial radii, to be kept constant throughout iteration
  nc = int(nr * Rc/Rp)
  if (x_H2O_tot==0):
    nm = nr - nc
    nw = 0
  else:
    nm = int(nr * Rm/Rp) - nc
    nw = nr - nm - nc

  # Initialization of arrays: surface values
  if Mw>0:
    density[nr-1] = rho_w
    alpha[nr-1] = alpha_w
    cp[nr-1] = cp_w
  elif Mm>0:
    density[nr-1] = rho_m
    alpha[nr-1] = alpha_m
    cp[nr-1] = cp_m
  else: # pure iron shell
    density[nr-1] = rho_c
    alpha[nr-1] = alpha_c
    cp[nr-1] = cp_c
    Rc = Rp

  # Initialization of arrays: interpolation over depth
  for i in range(0,nr):
    if i==0:
      r_prev = 0.0
    else:
      r_prev = radius[i-1]
    if i<nc:
      dr[i] = Rc/float(nc)
      density[i] = rho_c
      alpha[i] = alpha_c
      cp[i] = cp_c
    elif i<nc+nm:
      dr[i] = (Rm-Rc)/float(nm)
      density[i] = rho_m
      alpha[i] = alpha_m
      cp[i] = cp_m
    else:
      dr[i] = (Rp-Rm)/float(nw)
      density[i] = rho_w
      alpha[i] = alpha_w
      cp[i] = cp_w
    radius[i] = r_prev + dr[i]


  # pressure and temperature are interpolated from surface downwards
  # gravity has boundary condition 0 in center (and not at surface)
  pressure[nr-1] = Psurf # 1 bar surface pressure
  temperature[nr-1] = Tsurf # surface temperature
  gravity[nr-1] = G*M/Rp**2 # first guess surface gravity
  plid = Dlid*rho_m*gravity[nr-1] # first guess at plid, will be calculated below


  '''Start iteration to determine interior structure'''

  #print('It  Rp/1000  Rc/1000  rho_m  rho_c')
  #print('------------------------------------')

  iter = 1
  Store_V_vec_old = []
  Rp_old = 0
  while (abs(Rp-Rp_old) > tol) and (iter < maxIter):
      # store old Rp value to determine convergence
      Rp_old = Rp

      # average values will be re-determined from material properties
      rho_c = 0; rho_m = 0; rho_w = 0; vol_c = 0; vol_m = 0; vol_w = 0

      # update vectors for radius, gravity, pressure and temperature
      for i in range(0,nr):
        if i==0:
          r_prev = 0.0
        else:
          r_prev = radius[i-1]
        if i<nc:
          dr[i] = Rc/float(nc)
        elif i<nc+nm:
          dr[i] = (Rm-Rc)/float(nm)
        else:
          dr[i] = (Rp-Rm)/float(nw)
        radius[i] = r_prev + dr[i]
      #print('Rp:',Rp,radius[nr-1],' Rc:',Rc,radius[nc-1],nr,nc,nm,nw)

      # set gravity[0] with formula for homogeneous shell in center (formula below does only work for i>=1)
      gravity[0] = radius[0] * 4/3*math.pi*G*density[0]
      for i in range(1,nr):
          gravity[i] = gravity[i-1] + dr[i-1] * (4*math.pi*G*density[i-1] - 2*gravity[i-1]/radius[i-1])

      for i in range(nr-2,-1,-1):
          pressure[i] = pressure[i+1] + dr[i]*gravity[i]*density[i]
          if i>=nc+nm: # ocean layer, we assume here adiabatic profile from the surface
              temperature[i] = temperature[i+1] + dr[i]*alpha[i+1]/cp[i+1] * gravity[i+1]*temperature[i+1]
          elif Rm-radius[i]<Dlid: # in lithosphere
              if Mw>0:
                Ts = temperature[nc+nm]
              else:
                Ts = Tsurf
              if Tlid>0:
                  # linear increase of temperature in lithosphere for simplicity
                  temperature[i] = Ts + (Tlid-Ts)*(radius[nc+nm-1]-radius[i])/Dlid
              else:
                  temperature[i] = Ts + (get_Tmelt_MO(plid)-Ts)*(radius[nc+nm-1]-radius[i])/Dlid
          elif Rm-radius[i+1]<Dlid: # first grid point in mantle
              if Tlid>0:
                  temperature[i] = Tlid # Choose fixed, pre-defined temperature at bottom of lid
              else:
                  temperature[i] = get_Tmelt_MO(plid) # Choose temperature from end of magma ocean phase
              plid = pressure[i] # for next iteration to get T at lithosphere base in case that Tlid=0
          elif (i+1==nc):
              temperature[i] = temperature[i+1] + dr[i]*alpha[i+1]/cp[i+1] * gravity[i+1]*temperature[i+1]
              if DTcmb >= 0:
                  # Choose fixed, pre-defined temperature at Core-Mantle-Boundary (CMB)
                  temperature[i] = temperature[i] + DTcmb
              else:
                  # Choose temperature from end of magma ocean phase, scaled with abs(DTcmb) factor
                  temperature[i] = temperature[i] + (get_Tmelt_MO(pressure[i])-temperature[i]) * abs(DTcmb)
          else: # in convecting mantle or core
              temperature[i] = temperature[i+1] + dr[i]*alpha[i+1]/cp[i+1] * gravity[i+1]*temperature[i+1]
          #print(i,temperature[i],nc,nm,nr)

      # update material properties
      Store_V_vec = []
      ric = 0
      for i in range(nr): # from center to surface
          # get correct layer depending on core size, mantle phase transitions, and crust thickness
          # 7 layers in total: 6-core, 5-ppv, 4-pv, 3-ri, 2-wa, 1-ol, 0-cr
          if i < nc:
              # iron core
              if temperature[i]<get_Tmelt_core(pressure[i]):
                mat[i] = 8 # inner core
                ric = radius[i] # updated until outer core is reached
              else:
                mat[i] = 7 # outer core
              arr_species = ['fehcp']
              mole_vec = [1]
          elif i >= nc+nm:
              # water layer
              mat[i] = 0 # liquid water or water ice, phase defined below
              arr_species = ['h2o']
              [Tm,phase] = get_Tmelt_water(pressure[i])
              if temperature[i]<Tm:
                mat[i] = -phase # ice phases stored with negative values
              mole_vec = [1]
          elif pressure[i] >= (127 + 0.006*(temperature[i]-2840))*10**9:
              # post-perovskite
              mat[i] = 6
              arr_species = ['mppv', 'fppv','pe','wu']
              mole_vec = [0.5*(1-X_FeM_mol),0.5*(X_FeM_mol),0.5*(1-X_FeM_mol),0.5*(X_FeM_mol)]
          elif pressure[i] >= (22.9 - 0.0025*(temperature[i]-2260))*10**9:
              # perovskite
              mat[i] = 5
              arr_species = ['mgpv', 'fepv','pe','wu']
              mole_vec = [0.5*(1-X_FeM_mol),0.5*(X_FeM_mol),0.5*(1-X_FeM_mol),0.5*(X_FeM_mol)]
          elif (pressure[i] >= (6.2 + 16.7*(1-X_FeM_mol) + 0.005*(temperature[i]-2260))*10**9) & (radius[i] <= Rm-Dcr):
              # ringwoodite
              mat[i] = 4
              arr_species = ['mgri', 'feri']
              mole_vec = [1-X_FeM_mol,X_FeM_mol]
          elif (pressure[i] >= (4.92 + 5.4*(1-X_FeM_mol) + 0.0025*temperature[i])*10**9) & (radius[i] <= Rm-Dcr):
              # wadsleyite
              mat[i] = 3
              arr_species = ['mgwa', 'fewa']
              mole_vec = [1-X_FeM_mol,X_FeM_mol]
          elif radius[i] <= Rm-Dcr:
              # olivine
              mat[i] = 2
              arr_species = ['fo', 'fa']
              mole_vec = [1-X_FeM_mol,X_FeM_mol]
          else:
              # crust
              mat[i] = 1
              arr_species = ['an','di','qtz'] #Anorthite Feldspar Ca[Al2Si2]O8; Diopside CaMgSi2O6; Quartz SiO2
              mole_vec = [0.5, 0.25, 0.25]

          # mole fraction to mass fraction
          molmass = np.zeros(len(mole_vec))
          for k,species in enumerate(arr_species):
              res = values(species) # params for species
              molmass[k] = res.M
          mf_vec = mole_vec*molmass / np.sum(mole_vec*molmass)


          # calculate local thermodynamic properties based on an EOS
          if mat[i] >= 7:
              if mat[i] == 8:
                xelemc = xelem_ic
              else:
                xelemc = (xelem * radius[nc-1]**3 - xelem_ic*ric**3)/(radius[nc-1]**3-ric**3) # redistribute light elements into outer core, keep some in inner core
                # todo: adjust for slightly different density in inner and outer core, since xelemc is molar fraction, hence mass/molMass
              #print(ric,radius[nc],xelem,xelemc,xelem_ic)
              #cp[i],density[i],alpha[i],KT[i],KS[i],mu[i],V_vec = EOS_core(pressure[i]/10**9,temperature[i],xelemc)
              cp[i],density[i],alpha[i],KT[i],KS[i],mu[i],V_vec = EOS_core_mixed(pressure[i]/10**9,temperature[i],xC=xelemc[1], xSi=xelemc[0], xS=xelemc[2], xO=xelemc[3])

          else:
              if Store_V_vec_old == []:
                  cp[i],density[i],alpha[i],KT[i],KS[i],mu[i],V_vec = EOS_rock(pressure[i]/10**9,temperature[i],arr_species,mf_vec)
              else:
                  #print(i,V_vec)
                  cp[i],density[i],alpha[i],KT[i],KS[i],mu[i],V_vec = EOS_rock(pressure[i]/10**9,temperature[i],arr_species,mf_vec,Store_V_vec_old[i])
          Store_V_vec.append(V_vec)

          # check profiles
          #print(iter,radius[i]/1000,gravity[i],pressure[i]/10**9,density[i],temperature[i])

          # update mass vector (used here only for visualization)
          if i==0:
              mass[i] = 4*math.pi*radius[i]**3*density[i]
          else:
              mass[i] = mass[i-1] + (radius[i]-radius[i-1])*4*math.pi*radius[i]**2*density[i]

          #Get new average densities for radius update
          if i==0:
              vol = 4/3 * math.pi * radius[i]**3
          else:
              vol = 4/3 * math.pi * (radius[i]**3 - radius[i-1]**3)

          if i <= nc:
              rho_c = rho_c + density[i]*vol
              vol_c = vol_c + vol
          elif i <= nc+nm:
              rho_m = rho_m + density[i]*vol
              vol_m = vol_m + vol
          else:
              rho_w = rho_w + density[i]*vol
              vol_w = vol_w + vol

      # Error with surface density for iron incl. light species
      if density[nr-1] < 0:
          density[nr-1] = density[nr-2]

      Store_V_vec_old = Store_V_vec

      if vol_c==0:
          vol_c=1 # in case that no core exists
      if vol_m==0:
          vol_m=1 # in case that no mantle exists
      if vol_w==0:
          vol_w=1 # in case that no water layer exists

      rho_c = rho_c / vol_c
      rho_m = rho_m / vol_m
      rho_w = rho_w / vol_w

      # update radius for core and mantle
      if Mc==0:
        Rc = 0
      else:
        Rc = (3*Mc/(4*math.pi*rho_c))**(1/3)
      if Mm==0:
        Rm = Rc
      else:
        if (rho_m>0.0):
          Rm = (Rc**3 + 3*Mm/(4*math.pi*rho_m))**(1/3)
        else:
          Rm = Rc
      if Mw==0:
        Rp = Rm
      else:
        if (rho_w>0.0): # can happen if surface water layer is smaller than resolution between two uppermost grid points
          Rp = (Rm**3 + 3*Mw/(4*math.pi*rho_w))**(1/3)
        else:
          Rp = Rm

      #print('{0:2d} {1:8.2f} {2:8.2f} {3:7.1f} {4:7.1f}'.format(iter,Rp/1000,Rc/1000,rho_m,rho_c))

      iter=iter+1


  '''Post-processing'''

  # Additional properties computed from final iteration (i.e. without influence on interior structure)

  # seismic velocity profiles
  vP = np.sqrt((KS*10**9+4/3*mu*10**9)/density)*10**-3 # in km/s
  vS = np.sqrt(mu*10**9/density)*10**-3 # in km/s

  # electrical conductivity
  kB = 8.61733e-5
  for i in range(nr):
      T = temperature[i]

      if mat[i]<=0:
          elcond[i] = 1.0e-20
      elif mat[i]<=2: # olivine layer and crust
          if ec_model==1:
              # Xu dry profile
              elcond[i] = 10.0**2.69*math.exp(-1.62/(kB*T))
          elif ec_model==2:
              # electrical conductivity in upper mantle following Yoshino and Katsura 2013
              elcond[i] = 10.0**4.73*math.exp(-2.31/(kB*T)) \
              + 10.0**1.9*X_H2OM*math.exp(-(0.92-0.16*X_H2OM**(1.0/3.0))/(kB*T))
          else:
              # electrical conductivity in upper mantle following Yoshino and Katsura 2013 with iron
              elcond[i] = 10.0**4.73*math.exp(-2.31/(kB*T)) \
              + 10.0**2.98*X_FeM_mol*math.exp(-(1.71-2.0*X_FeM_mol**(1.0/3.0))/(kB*T)) \
              + 10.0**1.9*X_H2OM*math.exp(-(0.92-0.16*X_H2OM**(1.0/3.0))/(kB*T))
      elif (mat[i]==3): # wadsleyite layer
          if ec_model==1:
              # Xu dry profile
              elcond[i] = 10.0**3.29*math.exp(-1.29/(kB*T))
          elif ec_model==2:
              # electrical conductivity in upper mantle following Yoshino 2008
              elcond[i] = 399.0*math.exp(-1.49/(kB*T)) \
              + 7.74*X_H2OM*math.exp(-(0.68-0.02*X_H2OM**(1.0/3.0))/(kB*T))
          else:
              # electrical conductivity in upper mantle following Yoshino and Katsura 2013 with iron
              elcond[i] = 10.0**2.46*X_FeM_mol*math.exp(-(1.45-2.0*X_FeM_mol**(1.0/3.0))/(kB*T)) \
              + 10.0**1.4*X_H2OM*math.exp(-(0.83-0.2*X_H2OM**(1.0/3.0))/(kB*T))
      elif (mat[i]==4): # ringwoodite layer
          if ec_model==1:
              # Xu dry profile
              elcond[i] = 10.0**2.92*math.exp(-1.16/(kB*T))
          elif ec_model==2:
              # electrical conductivity in upper mantle following Yoshino 2008
              elcond[i] = 838.0*math.exp(-1.36/(kB*T)) \
              + 27.7*X_H2OM*math.exp(-(1.12-0.67*X_H2OM**(1.0/3.0))/(kB*T))
          elif ec_model==3:
              # electrical conductivity in upper mantle following Yoshino and Katsura 2013 with enthalpy and alpha from Yoshino&Katsura 2009
              elcond[i] = 10042*X_FeM_mol*math.exp(-(2.48-2.25*X_FeM_mol**(1.0/3.0))/(kB*T)) \
              + 10.0**1.44*X_H2OM*math.exp(-(1.12-0.67*X_H2OM**(1.0/3.0))/(kB*T))
          else:
              # electrical conductivity in upper mantle following Yoshino and Katsura 2013 with iron
              elcond[i] = 10.0**2.92*X_FeM_mol*math.exp(-(1.36-2.0*X_FeM_mol**(1.0/3.0))/(kB*T)) \
              + 10.0**1.44*X_H2OM*math.exp(-(1.12-0.67*X_H2OM**(1.0/3.0))/(kB*T))
      elif (mat[i]==5) or (mat[i]==6): # pv or ppv layer
          #  Xu 2000 lower mantle values (for pv, use here the same formula for ppv)
          elcond[i] = 0.6851*10**1.12*math.exp(-0.62/(kB*T)) \
                    + 0.3149*10**2.69*math.exp(-0.85/(kB*T))
      else: # profile not calculated for core, does not matter anyway for induction heating
          elcond[i] = math.nan

  # log10 values; in iron core ec=nan -> log profile is also nan
  elcond = np.log10(elcond)

  # moment of inertia factor

  IntVal = 0
  for i in range(nr):
    IntVal += density[i] * (radius[i]-0.5*dr[i])**4 * dr[i]

  MOI = IntVal * 8*math.pi/(3*M*Rp**2)

  # radius in Earth radii instead of m
  Rc_E = Rc / 6371000
  Rp_E = Rp / 6371000
  Rm_E = Rm / 6371000

  return Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat

# %%
from astropy import constants as const
from astropy import units as u

# Constantes
r_s = const.R_sun.to(u.au).value.item() #UA
m_s= const.M_sun.to(u.kg).value.item() #kg
T_sol=5772 #K
M_t= const.M_earth.to(u.kg).value.item() #kg
R_t= const.R_earth.to(u.km).value.item() #km
P_t= 1 #atm
UA=1.496e+11#m
R_sol=6.96*10**8 #m

# %% [markdown]
# # APLICAÇÃO PARA OS DEMAIS EXOPLAENTAS TIPO TERRA OU SUPER-TERRA

# %%
# Para  GJ 1002 b

mass_obs = 1.08 
radius_obs = 1.03
temp_obs = 288
P_p=1.05*10**5

sigma_M=0.13
sigma_R=0.2*radius_obs

n_samples = 1000
D_values = []
rho_value=[]
fe=35.0
h2o=0.06
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)

# %%
D_mean, D_std
# Out:
# (np.float64(0.35934959249440773), np.float64(0.04315144880477174))

# %%
rho_mean, rho_std
# Out:
# (np.float64(11409.51235471623), np.float64(162.4512567175813))

# %%
# Para  GJ 1002 C

mass_obs = 1.74
radius_obs = 1.18
temp_obs = 354
P_p=1.58*10**5 

sigma_M=0.17
sigma_R=0.2*radius_obs

n_samples = 1000
D_values = []
rho_value=[]
fe=35.0
h2o=0.0
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)

# %%
D_mean, D_std
# Out:
# (np.float64(0.2808847168228711), np.float64(0.001022015796574112))

# %%
rho_mean, rho_std
# Out:
# (np.float64(12401.877058567014), np.float64(251.34474038678843))

# %%
# Para  Kepler-138 e

mass_obs = 0.43
radius_obs = 0.797
temp_obs = 335
P_p=0.46*10**5

sigma_M=0.21
sigma_R=0.2*radius_obs

n_samples = 1000
D_values = []
rho_value=[]
fe=30.0
h2o=0.12
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 13: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 45: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 65: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 269: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 296: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 304: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 314: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 465: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 489: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 587: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 621: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 647: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 64.8
# percentage done 64.9
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 650: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 676: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 729: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 816: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 855: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 885: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 989: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)

# %%
D_mean, D_std
# Out:
# (np.float64(0.4766892006203673), np.float64(0.07897774721773333))

# %%
rho_mean, rho_std
# Out:
# (np.float64(9714.500839741135), np.float64(724.9635694756915))

# %%
# Para  Kepler-186 f
mass_obs = 1.71
radius_obs = 1.17
temp_obs = 253  
P_p=1.58*10**5
    
sigma_M=0.25*mass_obs
sigma_R=0.08

n_samples = 1000
D_values = []
rho_value=[]
fe=35.0
h2o=0.12
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.2904413745352691),
#  np.float64(0.023163235973057892),
#  np.float64(12318.500772987025),
#  np.float64(626.5688474680852))

# %%
# Para Proxima Cen b  

mass_obs = 1.055
radius_obs = 1.02
temp_obs = 274
    
P_p=1.04*10**5
    
sigma_M=0.055
sigma_R=0.2*radius_obs

n_samples = 1000
D_values = []
rho_value=[]
fe=35.0
h2o=0.12
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.354919076425151),
#  np.float64(0.015288209229404737),
#  np.float64(11355.897381416919),
#  np.float64(68.3368515982259))

# %%
# Para  TOI-700 d

mass_obs = 1.25
radius_obs = 1.073
temp_obs = 308
P_p=1.2*10**5

sigma_M=0.25*mass_obs
sigma_R=0.059

n_samples = 1000
D_values = []
rho_value=[]
fe=35.0
h2o=0.12
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.33825690066908004),
#  np.float64(0.0491844625129156),
#  np.float64(11641.597998396317),
#  np.float64(477.3920131675034))

# %%
# Para  TOI-700 e

mass_obs = 0.818
radius_obs = 0.953
temp_obs = 323
P_p=0.82*10**5

sigma_M=0.25*mass_obs
sigma_R=0.089

n_samples = 1000
D_values = []
rho_value=[]
fe=33.250
h2o=0.12
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.4767086923166746),
#  np.float64(0.04546843506658328),
#  np.float64(10923.276986119714),
#  np.float64(520.3762675438488))

# %%
# Para  Teegarden's Star c
mass_obs = 1.05
radius_obs = 1.02
temp_obs = 273
    
P_p=1.03*10**5
    
sigma_M=0.14
sigma_R=0.2*radius_obs
n_samples = 1000
D_values = []
rho_value=[]
fe=35.0
h2o=0.12
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.37671644595115866),
#  np.float64(0.05379296595329547),
#  np.float64(11364.593644827399),
#  np.float64(189.59768655954008))

# %%
# To  LHS 1140 b
mass_obs = 5.6
radius_obs = 1.73
temp_obs = 346
P_p=3.55*10**5

sigma_M=0.19
sigma_R=0.025

n_samples = 1000
D_values = []
rho_value=[]
fe=17.0
h2o=4.5
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.3367934298607965),
#  np.float64(0.0026701144960630803),
#  np.float64(17204.17244060828),
#  np.float64(190.29317019396942))

# %%
# To  tau Cet f
mass_obs = 3.93
radius_obs = 1.81
temp_obs = 251
P_p=1.46*10**5

sigma_M=1.37
sigma_R=0.2*radius_obs

n_samples = 1000
D_values = []
rho_value=[]
fe=9.50
h2o=55.0
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# Erro na iteração 37: cannot access local variable 'rho' where it is not associated with a value
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# Erro na iteração 97: cannot access local variable 'rho' where it is not associated with a value
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# Error, not enough iron in planet to have  0.1  as iron number -> adapt iron number!
# Erro na iteração 106: int() argument must be a string, a bytes-like object or a real number, not 'complex'
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# Erro na iteração 197: cannot access local variable 'rho' where it is not associated with a value
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# Erro na iteração 346: cannot access local variable 'rho' where it is not associated with a value
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# Erro na iteração 352: cannot access local variable 'rho' where it is not associated with a value
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# Erro na iteração 391: cannot access local variable 'rho' where it is not associated with a value
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# Erro na iteração 431: cannot access local variable 'rho' where it is not associated with a value
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# Erro na iteração 454: cannot access local variable 'rho' where it is not associated with a value
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# Erro na iteração 459: cannot access local variable 'rho' where it is not associated with a value
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# Erro na iteração 464: cannot access local variable 'rho' where it is not associated with a value
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# Erro na iteração 520: cannot access local variable 'rho' where it is not associated with a value
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# Erro na iteração 575: cannot access local variable 'rho' where it is not associated with a value
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# Erro na iteração 606: cannot access local variable 'rho' where it is not associated with a value
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# Erro na iteração 670: cannot access local variable 'rho' where it is not associated with a value
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# Erro na iteração 697: cannot access local variable 'rho' where it is not associated with a value
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# Erro na iteração 706: cannot access local variable 'rho' where it is not associated with a value
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# Erro na iteração 734: cannot access local variable 'rho' where it is not associated with a value
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# Erro na iteração 753: cannot access local variable 'rho' where it is not associated with a value
# Erro na iteração 754: cannot access local variable 'rho' where it is not associated with a value
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# Erro na iteração 893: cannot access local variable 'rho' where it is not associated with a value
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# Erro na iteração 908: cannot access local variable 'rho' where it is not associated with a value
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# Erro na iteração 973: cannot access local variable 'rho' where it is not associated with a value
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# Erro na iteração 997: cannot access local variable 'rho' where it is not associated with a value
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.25290232483848535),
#  np.float64(0.025800989277775598),
#  np.float64(14214.16109223325),
#  np.float64(1475.6206146758461))

# %%
# To   K2-18 b
mass_obs = 8.92
radius_obs = 2.37
temp_obs = 317
    
P_p=2.56*10**5

sigma_M=1.7
sigma_R=0.22

n_samples = 1000
D_values = []
rho_value=[]
fe=10.0
h2o=85.0
for i in range(n_samples):
    try:
        M_planet_sample = np.random.normal(mass_obs, sigma_M)
        R_planet_sample = np.random.normal(radius_obs, sigma_R)

        Rp_E,Rc_E,Rm_E,MOI,radius,density,gravity,pressure,temperature,alpha,cp,mass,elcond,vP,vS,KT,KS,mu,mat = interior_structure(
            M_planet_sample, fe, h2o, temp_obs, P_p
        )

        outer_core_indices = np.where(mat == 7)[0]
        inner_core_indices = np.where(mat == 8)[0]

        if len(outer_core_indices) > 0:
            Rc = radius[outer_core_indices[-1]]
            Ric = radius[outer_core_indices[0]] if len(inner_core_indices) > 0 else 0
        else:
            all_core_indices = np.where((mat == 7) | (mat == 8))[0]
            Rc = radius[all_core_indices[-1]]
            Ric = 0

        D = Rc - Ric
        D_values.append(D/(radius_obs*R_t*1000))

        if len(outer_core_indices) > 0:
            rho_core_mean = np.mean(density[outer_core_indices])
            rho_value.append(rho_core_mean)
        else:
            print("The planet does not have a liquid outer core.!")

    except Exception as e:
        print(f"Erro na iteração {i}: {e}")
        continue

    print('percentage done', (i)*100/n_samples)
# Out:
# percentage done 0.0
# percentage done 0.1
# percentage done 0.2
# percentage done 0.3
# percentage done 0.4
# percentage done 0.5
# percentage done 0.6
# percentage done 0.7
# percentage done 0.8
# percentage done 0.9
# percentage done 1.0
# percentage done 1.1
# percentage done 1.2
# percentage done 1.3
# percentage done 1.4
# percentage done 1.5
# percentage done 1.6
# percentage done 1.7
# percentage done 1.8
# percentage done 1.9
# percentage done 2.0
# percentage done 2.1
# percentage done 2.2
# percentage done 2.3
# percentage done 2.4
# percentage done 2.5
# percentage done 2.6
# percentage done 2.7
# percentage done 2.8
# percentage done 2.9
# percentage done 3.0
# percentage done 3.1
# percentage done 3.2
# percentage done 3.3
# percentage done 3.4
# percentage done 3.5
# percentage done 3.6
# percentage done 3.7
# percentage done 3.8
# percentage done 3.9
# percentage done 4.0
# percentage done 4.1
# percentage done 4.2
# percentage done 4.3
# percentage done 4.4
# percentage done 4.5
# percentage done 4.6
# percentage done 4.7
# percentage done 4.8
# percentage done 4.9
# percentage done 5.0
# percentage done 5.1
# percentage done 5.2
# percentage done 5.3
# percentage done 5.4
# percentage done 5.5
# percentage done 5.6
# percentage done 5.7
# percentage done 5.8
# percentage done 5.9
# percentage done 6.0
# percentage done 6.1
# percentage done 6.2
# percentage done 6.3
# percentage done 6.4
# percentage done 6.5
# percentage done 6.6
# percentage done 6.7
# percentage done 6.8
# percentage done 6.9
# percentage done 7.0
# percentage done 7.1
# percentage done 7.2
# percentage done 7.3
# percentage done 7.4
# percentage done 7.5
# percentage done 7.6
# percentage done 7.7
# percentage done 7.8
# percentage done 7.9
# percentage done 8.0
# percentage done 8.1
# percentage done 8.2
# percentage done 8.3
# percentage done 8.4
# percentage done 8.5
# percentage done 8.6
# percentage done 8.7
# percentage done 8.8
# percentage done 8.9
# percentage done 9.0
# percentage done 9.1
# percentage done 9.2
# percentage done 9.3
# percentage done 9.4
# percentage done 9.5
# percentage done 9.6
# percentage done 9.7
# percentage done 9.8
# percentage done 9.9
# percentage done 10.0
# percentage done 10.1
# percentage done 10.2
# percentage done 10.3
# percentage done 10.4
# percentage done 10.5
# percentage done 10.6
# percentage done 10.7
# percentage done 10.8
# percentage done 10.9
# percentage done 11.0
# percentage done 11.1
# percentage done 11.2
# percentage done 11.3
# percentage done 11.4
# percentage done 11.5
# percentage done 11.6
# percentage done 11.7
# percentage done 11.8
# percentage done 11.9
# percentage done 12.0
# percentage done 12.1
# percentage done 12.2
# percentage done 12.3
# percentage done 12.4
# percentage done 12.5
# percentage done 12.6
# percentage done 12.7
# percentage done 12.8
# percentage done 12.9
# percentage done 13.0
# percentage done 13.1
# percentage done 13.2
# percentage done 13.3
# percentage done 13.4
# percentage done 13.5
# percentage done 13.6
# percentage done 13.7
# percentage done 13.8
# percentage done 13.9
# percentage done 14.0
# percentage done 14.1
# percentage done 14.2
# percentage done 14.3
# percentage done 14.4
# percentage done 14.5
# percentage done 14.6
# percentage done 14.7
# percentage done 14.8
# percentage done 14.9
# percentage done 15.0
# percentage done 15.1
# percentage done 15.2
# percentage done 15.3
# percentage done 15.4
# percentage done 15.5
# percentage done 15.6
# percentage done 15.7
# percentage done 15.8
# percentage done 15.9
# percentage done 16.0
# percentage done 16.1
# percentage done 16.2
# percentage done 16.3
# percentage done 16.4
# percentage done 16.5
# percentage done 16.6
# percentage done 16.7
# percentage done 16.8
# percentage done 16.9
# percentage done 17.0
# percentage done 17.1
# percentage done 17.2
# percentage done 17.3
# percentage done 17.4
# percentage done 17.5
# percentage done 17.6
# percentage done 17.7
# percentage done 17.8
# percentage done 17.9
# percentage done 18.0
# percentage done 18.1
# percentage done 18.2
# percentage done 18.3
# percentage done 18.4
# percentage done 18.5
# percentage done 18.6
# percentage done 18.7
# percentage done 18.8
# percentage done 18.9
# percentage done 19.0
# percentage done 19.1
# percentage done 19.2
# percentage done 19.3
# percentage done 19.4
# percentage done 19.5
# percentage done 19.6
# percentage done 19.7
# percentage done 19.8
# percentage done 19.9
# percentage done 20.0
# percentage done 20.1
# percentage done 20.2
# percentage done 20.3
# percentage done 20.4
# percentage done 20.5
# percentage done 20.6
# percentage done 20.7
# percentage done 20.8
# percentage done 20.9
# percentage done 21.0
# percentage done 21.1
# percentage done 21.2
# percentage done 21.3
# percentage done 21.4
# percentage done 21.5
# percentage done 21.6
# percentage done 21.7
# percentage done 21.8
# percentage done 21.9
# percentage done 22.0
# percentage done 22.1
# percentage done 22.2
# percentage done 22.3
# percentage done 22.4
# percentage done 22.5
# percentage done 22.6
# percentage done 22.7
# percentage done 22.8
# percentage done 22.9
# percentage done 23.0
# percentage done 23.1
# percentage done 23.2
# percentage done 23.3
# percentage done 23.4
# percentage done 23.5
# percentage done 23.6
# percentage done 23.7
# percentage done 23.8
# percentage done 23.9
# percentage done 24.0
# percentage done 24.1
# percentage done 24.2
# percentage done 24.3
# percentage done 24.4
# percentage done 24.5
# percentage done 24.6
# percentage done 24.7
# percentage done 24.8
# percentage done 24.9
# percentage done 25.0
# percentage done 25.1
# percentage done 25.2
# percentage done 25.3
# percentage done 25.4
# percentage done 25.5
# percentage done 25.6
# percentage done 25.7
# percentage done 25.8
# percentage done 25.9
# percentage done 26.0
# percentage done 26.1
# percentage done 26.2
# percentage done 26.3
# percentage done 26.4
# percentage done 26.5
# percentage done 26.6
# percentage done 26.7
# percentage done 26.8
# percentage done 26.9
# percentage done 27.0
# percentage done 27.1
# percentage done 27.2
# percentage done 27.3
# percentage done 27.4
# percentage done 27.5
# percentage done 27.6
# percentage done 27.7
# percentage done 27.8
# percentage done 27.9
# percentage done 28.0
# percentage done 28.1
# percentage done 28.2
# percentage done 28.3
# percentage done 28.4
# percentage done 28.5
# percentage done 28.6
# percentage done 28.7
# percentage done 28.8
# percentage done 28.9
# percentage done 29.0
# percentage done 29.1
# percentage done 29.2
# percentage done 29.3
# percentage done 29.4
# percentage done 29.5
# percentage done 29.6
# percentage done 29.7
# percentage done 29.8
# percentage done 29.9
# percentage done 30.0
# percentage done 30.1
# percentage done 30.2
# percentage done 30.3
# percentage done 30.4
# percentage done 30.5
# percentage done 30.6
# percentage done 30.7
# percentage done 30.8
# percentage done 30.9
# percentage done 31.0
# percentage done 31.1
# percentage done 31.2
# percentage done 31.3
# percentage done 31.4
# percentage done 31.5
# percentage done 31.6
# percentage done 31.7
# percentage done 31.8
# percentage done 31.9
# percentage done 32.0
# percentage done 32.1
# percentage done 32.2
# percentage done 32.3
# percentage done 32.4
# percentage done 32.5
# percentage done 32.6
# percentage done 32.7
# percentage done 32.8
# percentage done 32.9
# percentage done 33.0
# percentage done 33.1
# percentage done 33.2
# percentage done 33.3
# percentage done 33.4
# percentage done 33.5
# percentage done 33.6
# percentage done 33.7
# percentage done 33.8
# percentage done 33.9
# percentage done 34.0
# percentage done 34.1
# percentage done 34.2
# percentage done 34.3
# percentage done 34.4
# percentage done 34.5
# percentage done 34.6
# percentage done 34.7
# percentage done 34.8
# percentage done 34.9
# percentage done 35.0
# percentage done 35.1
# percentage done 35.2
# percentage done 35.3
# percentage done 35.4
# percentage done 35.5
# percentage done 35.6
# percentage done 35.7
# percentage done 35.8
# percentage done 35.9
# percentage done 36.0
# percentage done 36.1
# percentage done 36.2
# percentage done 36.3
# percentage done 36.4
# percentage done 36.5
# percentage done 36.6
# percentage done 36.7
# percentage done 36.8
# percentage done 36.9
# percentage done 37.0
# percentage done 37.1
# percentage done 37.2
# percentage done 37.3
# percentage done 37.4
# percentage done 37.5
# percentage done 37.6
# percentage done 37.7
# percentage done 37.8
# percentage done 37.9
# percentage done 38.0
# percentage done 38.1
# percentage done 38.2
# percentage done 38.3
# percentage done 38.4
# percentage done 38.5
# percentage done 38.6
# percentage done 38.7
# percentage done 38.8
# percentage done 38.9
# percentage done 39.0
# percentage done 39.1
# percentage done 39.2
# percentage done 39.3
# percentage done 39.4
# percentage done 39.5
# percentage done 39.6
# percentage done 39.7
# percentage done 39.8
# percentage done 39.9
# percentage done 40.0
# percentage done 40.1
# percentage done 40.2
# percentage done 40.3
# percentage done 40.4
# percentage done 40.5
# percentage done 40.6
# percentage done 40.7
# percentage done 40.8
# percentage done 40.9
# percentage done 41.0
# percentage done 41.1
# percentage done 41.2
# percentage done 41.3
# percentage done 41.4
# percentage done 41.5
# percentage done 41.6
# percentage done 41.7
# percentage done 41.8
# percentage done 41.9
# percentage done 42.0
# percentage done 42.1
# percentage done 42.2
# percentage done 42.3
# percentage done 42.4
# percentage done 42.5
# percentage done 42.6
# percentage done 42.7
# percentage done 42.8
# percentage done 42.9
# percentage done 43.0
# percentage done 43.1
# percentage done 43.2
# percentage done 43.3
# percentage done 43.4
# percentage done 43.5
# percentage done 43.6
# percentage done 43.7
# percentage done 43.8
# percentage done 43.9
# percentage done 44.0
# percentage done 44.1
# percentage done 44.2
# percentage done 44.3
# percentage done 44.4
# percentage done 44.5
# percentage done 44.6
# percentage done 44.7
# percentage done 44.8
# percentage done 44.9
# percentage done 45.0
# percentage done 45.1
# percentage done 45.2
# percentage done 45.3
# percentage done 45.4
# percentage done 45.5
# percentage done 45.6
# percentage done 45.7
# percentage done 45.8
# percentage done 45.9
# percentage done 46.0
# percentage done 46.1
# percentage done 46.2
# percentage done 46.3
# percentage done 46.4
# percentage done 46.5
# percentage done 46.6
# percentage done 46.7
# percentage done 46.8
# percentage done 46.9
# percentage done 47.0
# percentage done 47.1
# percentage done 47.2
# percentage done 47.3
# percentage done 47.4
# percentage done 47.5
# percentage done 47.6
# percentage done 47.7
# percentage done 47.8
# percentage done 47.9
# percentage done 48.0
# percentage done 48.1
# percentage done 48.2
# percentage done 48.3
# percentage done 48.4
# percentage done 48.5
# percentage done 48.6
# percentage done 48.7
# percentage done 48.8
# percentage done 48.9
# percentage done 49.0
# percentage done 49.1
# percentage done 49.2
# percentage done 49.3
# percentage done 49.4
# percentage done 49.5
# percentage done 49.6
# percentage done 49.7
# percentage done 49.8
# percentage done 49.9
# percentage done 50.0
# percentage done 50.1
# percentage done 50.2
# percentage done 50.3
# percentage done 50.4
# percentage done 50.5
# percentage done 50.6
# percentage done 50.7
# percentage done 50.8
# percentage done 50.9
# percentage done 51.0
# percentage done 51.1
# percentage done 51.2
# percentage done 51.3
# percentage done 51.4
# percentage done 51.5
# percentage done 51.6
# percentage done 51.7
# percentage done 51.8
# percentage done 51.9
# percentage done 52.0
# percentage done 52.1
# percentage done 52.2
# percentage done 52.3
# percentage done 52.4
# percentage done 52.5
# percentage done 52.6
# percentage done 52.7
# percentage done 52.8
# percentage done 52.9
# percentage done 53.0
# percentage done 53.1
# percentage done 53.2
# percentage done 53.3
# percentage done 53.4
# percentage done 53.5
# percentage done 53.6
# percentage done 53.7
# percentage done 53.8
# percentage done 53.9
# percentage done 54.0
# percentage done 54.1
# percentage done 54.2
# percentage done 54.3
# percentage done 54.4
# percentage done 54.5
# percentage done 54.6
# percentage done 54.7
# percentage done 54.8
# percentage done 54.9
# percentage done 55.0
# percentage done 55.1
# percentage done 55.2
# percentage done 55.3
# percentage done 55.4
# percentage done 55.5
# percentage done 55.6
# percentage done 55.7
# percentage done 55.8
# percentage done 55.9
# percentage done 56.0
# percentage done 56.1
# percentage done 56.2
# percentage done 56.3
# percentage done 56.4
# percentage done 56.5
# percentage done 56.6
# percentage done 56.7
# percentage done 56.8
# percentage done 56.9
# percentage done 57.0
# percentage done 57.1
# percentage done 57.2
# percentage done 57.3
# percentage done 57.4
# percentage done 57.5
# percentage done 57.6
# percentage done 57.7
# percentage done 57.8
# percentage done 57.9
# percentage done 58.0
# percentage done 58.1
# percentage done 58.2
# percentage done 58.3
# percentage done 58.4
# percentage done 58.5
# percentage done 58.6
# percentage done 58.7
# percentage done 58.8
# percentage done 58.9
# percentage done 59.0
# percentage done 59.1
# percentage done 59.2
# percentage done 59.3
# percentage done 59.4
# percentage done 59.5
# percentage done 59.6
# percentage done 59.7
# percentage done 59.8
# percentage done 59.9
# percentage done 60.0
# percentage done 60.1
# percentage done 60.2
# percentage done 60.3
# percentage done 60.4
# percentage done 60.5
# percentage done 60.6
# percentage done 60.7
# percentage done 60.8
# percentage done 60.9
# percentage done 61.0
# percentage done 61.1
# percentage done 61.2
# percentage done 61.3
# percentage done 61.4
# percentage done 61.5
# percentage done 61.6
# percentage done 61.7
# percentage done 61.8
# percentage done 61.9
# percentage done 62.0
# percentage done 62.1
# percentage done 62.2
# percentage done 62.3
# percentage done 62.4
# percentage done 62.5
# percentage done 62.6
# percentage done 62.7
# percentage done 62.8
# percentage done 62.9
# percentage done 63.0
# percentage done 63.1
# percentage done 63.2
# percentage done 63.3
# percentage done 63.4
# percentage done 63.5
# percentage done 63.6
# percentage done 63.7
# percentage done 63.8
# percentage done 63.9
# percentage done 64.0
# percentage done 64.1
# percentage done 64.2
# percentage done 64.3
# percentage done 64.4
# percentage done 64.5
# percentage done 64.6
# percentage done 64.7
# percentage done 64.8
# percentage done 64.9
# percentage done 65.0
# percentage done 65.1
# percentage done 65.2
# percentage done 65.3
# percentage done 65.4
# percentage done 65.5
# percentage done 65.6
# percentage done 65.7
# percentage done 65.8
# percentage done 65.9
# percentage done 66.0
# percentage done 66.1
# percentage done 66.2
# percentage done 66.3
# percentage done 66.4
# percentage done 66.5
# percentage done 66.6
# percentage done 66.7
# percentage done 66.8
# percentage done 66.9
# percentage done 67.0
# percentage done 67.1
# percentage done 67.2
# percentage done 67.3
# percentage done 67.4
# percentage done 67.5
# percentage done 67.6
# percentage done 67.7
# percentage done 67.8
# percentage done 67.9
# percentage done 68.0
# percentage done 68.1
# percentage done 68.2
# percentage done 68.3
# percentage done 68.4
# percentage done 68.5
# percentage done 68.6
# percentage done 68.7
# percentage done 68.8
# percentage done 68.9
# percentage done 69.0
# percentage done 69.1
# percentage done 69.2
# percentage done 69.3
# percentage done 69.4
# percentage done 69.5
# percentage done 69.6
# percentage done 69.7
# percentage done 69.8
# percentage done 69.9
# percentage done 70.0
# percentage done 70.1
# percentage done 70.2
# percentage done 70.3
# percentage done 70.4
# percentage done 70.5
# percentage done 70.6
# percentage done 70.7
# percentage done 70.8
# percentage done 70.9
# percentage done 71.0
# percentage done 71.1
# percentage done 71.2
# percentage done 71.3
# percentage done 71.4
# percentage done 71.5
# percentage done 71.6
# percentage done 71.7
# percentage done 71.8
# percentage done 71.9
# percentage done 72.0
# percentage done 72.1
# percentage done 72.2
# percentage done 72.3
# percentage done 72.4
# percentage done 72.5
# percentage done 72.6
# percentage done 72.7
# percentage done 72.8
# percentage done 72.9
# percentage done 73.0
# percentage done 73.1
# percentage done 73.2
# percentage done 73.3
# percentage done 73.4
# percentage done 73.5
# percentage done 73.6
# percentage done 73.7
# percentage done 73.8
# percentage done 73.9
# percentage done 74.0
# percentage done 74.1
# percentage done 74.2
# percentage done 74.3
# percentage done 74.4
# percentage done 74.5
# percentage done 74.6
# percentage done 74.7
# percentage done 74.8
# percentage done 74.9
# percentage done 75.0
# percentage done 75.1
# percentage done 75.2
# percentage done 75.3
# percentage done 75.4
# percentage done 75.5
# percentage done 75.6
# percentage done 75.7
# percentage done 75.8
# percentage done 75.9
# percentage done 76.0
# percentage done 76.1
# percentage done 76.2
# percentage done 76.3
# percentage done 76.4
# percentage done 76.5
# percentage done 76.6
# percentage done 76.7
# percentage done 76.8
# percentage done 76.9
# percentage done 77.0
# percentage done 77.1
# percentage done 77.2
# percentage done 77.3
# percentage done 77.4
# percentage done 77.5
# percentage done 77.6
# percentage done 77.7
# percentage done 77.8
# percentage done 77.9
# percentage done 78.0
# percentage done 78.1
# percentage done 78.2
# percentage done 78.3
# percentage done 78.4
# percentage done 78.5
# percentage done 78.6
# percentage done 78.7
# percentage done 78.8
# percentage done 78.9
# percentage done 79.0
# percentage done 79.1
# percentage done 79.2
# percentage done 79.3
# percentage done 79.4
# percentage done 79.5
# percentage done 79.6
# percentage done 79.7
# percentage done 79.8
# percentage done 79.9
# percentage done 80.0
# percentage done 80.1
# percentage done 80.2
# percentage done 80.3
# percentage done 80.4
# percentage done 80.5
# percentage done 80.6
# percentage done 80.7
# percentage done 80.8
# percentage done 80.9
# percentage done 81.0
# percentage done 81.1
# percentage done 81.2
# percentage done 81.3
# percentage done 81.4
# percentage done 81.5
# percentage done 81.6
# percentage done 81.7
# percentage done 81.8
# percentage done 81.9
# percentage done 82.0
# percentage done 82.1
# percentage done 82.2
# percentage done 82.3
# percentage done 82.4
# percentage done 82.5
# percentage done 82.6
# percentage done 82.7
# percentage done 82.8
# percentage done 82.9
# percentage done 83.0
# percentage done 83.1
# percentage done 83.2
# percentage done 83.3
# percentage done 83.4
# percentage done 83.5
# percentage done 83.6
# percentage done 83.7
# percentage done 83.8
# percentage done 83.9
# percentage done 84.0
# percentage done 84.1
# percentage done 84.2
# percentage done 84.3
# percentage done 84.4
# percentage done 84.5
# percentage done 84.6
# percentage done 84.7
# percentage done 84.8
# percentage done 84.9
# percentage done 85.0
# percentage done 85.1
# percentage done 85.2
# percentage done 85.3
# percentage done 85.4
# percentage done 85.5
# percentage done 85.6
# percentage done 85.7
# percentage done 85.8
# percentage done 85.9
# percentage done 86.0
# percentage done 86.1
# percentage done 86.2
# percentage done 86.3
# percentage done 86.4
# percentage done 86.5
# percentage done 86.6
# percentage done 86.7
# percentage done 86.8
# percentage done 86.9
# percentage done 87.0
# percentage done 87.1
# percentage done 87.2
# percentage done 87.3
# percentage done 87.4
# percentage done 87.5
# percentage done 87.6
# percentage done 87.7
# percentage done 87.8
# percentage done 87.9
# percentage done 88.0
# percentage done 88.1
# percentage done 88.2
# percentage done 88.3
# percentage done 88.4
# percentage done 88.5
# percentage done 88.6
# percentage done 88.7
# percentage done 88.8
# percentage done 88.9
# percentage done 89.0
# percentage done 89.1
# percentage done 89.2
# percentage done 89.3
# percentage done 89.4
# percentage done 89.5
# percentage done 89.6
# percentage done 89.7
# percentage done 89.8
# percentage done 89.9
# percentage done 90.0
# percentage done 90.1
# percentage done 90.2
# percentage done 90.3
# percentage done 90.4
# percentage done 90.5
# percentage done 90.6
# percentage done 90.7
# percentage done 90.8
# percentage done 90.9
# percentage done 91.0
# percentage done 91.1
# percentage done 91.2
# percentage done 91.3
# percentage done 91.4
# percentage done 91.5
# percentage done 91.6
# percentage done 91.7
# percentage done 91.8
# percentage done 91.9
# percentage done 92.0
# percentage done 92.1
# percentage done 92.2
# percentage done 92.3
# percentage done 92.4
# percentage done 92.5
# percentage done 92.6
# percentage done 92.7
# percentage done 92.8
# percentage done 92.9
# percentage done 93.0
# percentage done 93.1
# percentage done 93.2
# percentage done 93.3
# percentage done 93.4
# percentage done 93.5
# percentage done 93.6
# percentage done 93.7
# percentage done 93.8
# percentage done 93.9
# percentage done 94.0
# percentage done 94.1
# percentage done 94.2
# percentage done 94.3
# percentage done 94.4
# percentage done 94.5
# percentage done 94.6
# percentage done 94.7
# percentage done 94.8
# percentage done 94.9
# percentage done 95.0
# percentage done 95.1
# percentage done 95.2
# percentage done 95.3
# percentage done 95.4
# percentage done 95.5
# percentage done 95.6
# percentage done 95.7
# percentage done 95.8
# percentage done 95.9
# percentage done 96.0
# percentage done 96.1
# percentage done 96.2
# percentage done 96.3
# percentage done 96.4
# percentage done 96.5
# percentage done 96.6
# percentage done 96.7
# percentage done 96.8
# percentage done 96.9
# percentage done 97.0
# percentage done 97.1
# percentage done 97.2
# percentage done 97.3
# percentage done 97.4
# percentage done 97.5
# percentage done 97.6
# percentage done 97.7
# percentage done 97.8
# percentage done 97.9
# percentage done 98.0
# percentage done 98.1
# percentage done 98.2
# percentage done 98.3
# percentage done 98.4
# percentage done 98.5
# percentage done 98.6
# percentage done 98.7
# percentage done 98.8
# percentage done 98.9
# percentage done 99.0
# percentage done 99.1
# percentage done 99.2
# percentage done 99.3
# percentage done 99.4
# percentage done 99.5
# percentage done 99.6
# percentage done 99.7
# percentage done 99.8
# percentage done 99.9

# %%
D_mean = np.mean(D_values)
D_std = np.std(D_values)
rho_mean = np.mean(rho_value)
rho_std = np.std(rho_value)
D_mean, D_std, rho_mean, rho_std
# Out:
# (np.float64(0.27186196296733234),
#  np.float64(0.01279171433487172),
#  np.float64(17141.002969597674),
#  np.float64(1069.821365239682))
